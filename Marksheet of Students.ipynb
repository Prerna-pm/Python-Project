# %% [markdown]
# ![Screenshot (174).png](attachment:b5866b85-ed61-494b-941c-3ad7a6d9cbef.png)

# %% [markdown]
# ![Screenshot (168).png](attachment:b5aaad57-18f5-403c-a5f6-75a87e521e48.png)

# %% [markdown]
# ![Screenshot (177).png](attachment:05e12a93-e91f-497a-a40a-11759a1ba987.png)

# %% [markdown]
# ![Screenshot (179).png](attachment:3530ebbb-aa85-4fee-9f84-bb0d8a991f83.png)

# %%
Students = {"Abhishek Malhan":{"English":81,"Hindi":72,"Maths":79,"Science":86,"Social Studies":69},
            "Aradhya Bansal":{"English":95,"Hindi":88,"Maths":85,"Science":92,"Social Studies":90},
            "Ansh Sharma":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Aditya Rajput":{"English":32,"Hindi":30,"Maths":27,"Science":21,"Social Studies":29},
            "Bhavya Seth":{"English":70,"Hindi":72,"Maths":65,"Science":74,"Social Studies":78},
            "Bhumika Ratan":{"English":55,"Hindi":43,"Maths":39,"Science":49,"Social Studies":37},
            "Chetan Anand":{"English":88,"Hindi":60,"Maths":55,"Science":48,"Social Studies":74},
            "Chirag Parswan":{"English":89,"Hindi":92,"Maths":78,"Science":69,"Social Studies":85},
            "Dev Jindal":{"English":39,"Hindi":40,"Maths":67,"Science":28,"Social Studies":34},
            "Divya":{"English":56,"Hindi":59,"Maths":49,"Science":52,"Social Studies":47},
            "Divyanshu Mahajan":{"English":43,"Hindi":50,"Maths":72,"Science":66,"Social Studies":57},
            "Drishti Oberoi":{"English":78,"Hindi":49,"Maths":72,"Science":50,"Social Studies":56},
            "Gaurav Kumar":{"English":55,"Hindi":60,"Maths":77,"Science":89,"Social Studies":72},
            "Gautam Nijhawan":{"English":75,"Hindi":90,"Maths":67,"Science":65,"Social Studies":42},
            "Himanshu Rajput":{"English":66,"Hindi":82,"Maths":89,"Science":64,"Social Studies":57},
            "Harshit Sethi":{"English":85,"Hindi":80,"Maths":57,"Science":58,"Social Studies":60},
            "Hitika Verma":{"English":72,"Hindi":83,"Maths":77,"Science":38,"Social Studies":62},
            "Isha Yadav":{"English":64,"Hindi":60,"Maths":47,"Science":66,"Social Studies":57},
            "Ishaan Gupta":{"English":61,"Hindi":73,"Maths":53,"Science":60,"Social Studies":49},
            "Ishita Goel":{"English":78,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Kishan Goyal":{"English":68,"Hindi":62,"Maths":79,"Science":32,"Social Studies":45},
            "Khushi Singh":{"English":35,"Hindi":40,"Maths":32,"Science":29,"Social Studies":47},
            "Kunal Bisht":{"English":24,"Hindi":29,"Maths":32,"Science":30,"Social Studies":27},
            "Manisha Belwal":{"English":68,"Hindi":65,"Maths":49,"Science":58,"Social Studies":45},
            "Manni":{"English":72,"Hindi":81,"Maths":87,"Science":76,"Social Studies":80},
            "Mayank Sharma":{"English":75,"Hindi":60,"Maths":47,"Science":28,"Social Studies":32},
            "Mishika Rana":{"English":82,"Hindi":70,"Maths":67,"Science":89,"Social Studies":78},
            "Narendra Modi":{"English":43,"Hindi":89,"Maths":62,"Science":39,"Social Studies":91},
            "Netanya":{"English":64,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Nishtha Goyal":{"English":39,"Hindi":40,"Maths":26,"Science":36,"Social Studies":33},
            "Pratham":{"English":82,"Hindi":77,"Maths":90,"Science":78,"Social Studies":82},
            "Prerna Mehta":{"English":98,"Hindi":90,"Maths":88,"Science":92,"Social Studies":85},
            "Priyanshu Gupta":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Rahul Sharma":{"English":33,"Hindi":47,"Maths":34,"Science":11,"Social Studies":22},
            "Rohit Gujjar":{"English":62,"Hindi":71,"Maths":51,"Science":45,"Social Studies":58},
            "Saksham Singh":{"English":66,"Hindi":72,"Maths":53,"Science":59,"Social Studies":55},
            "Siddharth":{"English":72,"Hindi":80,"Maths":63,"Science":81,"Social Studies":52},
            "Shivani":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Sneha Jindal":{"English":59,"Hindi":70,"Maths":39,"Science":56,"Social Studies":64},
            "Swati Malik":{"English":93,"Hindi":89,"Maths":72,"Science":76,"Social Studies":69},
            "Tamana":{"English":50,"Hindi":46,"Maths":48,"Science":44,"Social Studies":34},
            "Tanupriya Pal":{"English":85,"Hindi":80,"Maths":79,"Science":82,"Social Studies":64},
            "Tushar":{"English":75,"Hindi":68,"Maths":79,"Science":65,"Social Studies":60},
            "Udayveer":{"English":92,"Hindi":80,"Maths":85,"Science":88,"Social Studies":73},
            "Utkarsh Singh":{"English":32,"Hindi":39,"Maths":28,"Science":34,"Social Studies":30},
            "Vaibhav Bhardwaj":{"English":69,"Hindi":70,"Maths":78,"Science":56,"Social Studies":65},
            "Vansh":{"English":40,"Hindi":53,"Maths":32,"Science":48,"Social Studies":31},
            "Vaani Mehta":{"English":52,"Hindi":41,"Maths":34,"Science":40,"Social Studies":35},
            "Virat Kohli":{"English":88,"Hindi":77,"Maths":90,"Science":74,"Social Studies":67},
            "Yashi":{"English":90,"Hindi":91,"Maths":83,"Science":77,"Social Studies":85}}

# %%
dic = {1:"Abhishek Malhan", 2:"Aradhya Bansal", 3:"Ansh Sharma", 4:"Aditya Rajput", 5:"Bhavya Seth", 
       6:"Bhumika Ratan", 7:"Chetan Anand", 8:"Chirag Parswan", 9:"Dev Jindal", 10:"Divya", 
       11:"Divyanshu Mahajan", 12:"Drishti Oberoi", 13:"Gaurav Kumar", 14:"Gautam Nijhawan", 15:"Himanshu Rajput",
       16:"Harshit Sethi", 17:"Hitika Verma", 18:"Isha Yadav", 19:"Ishaan Gupta", 20:"Ishita Goel",
       21:"Kishan Goyal", 22:"Khushi Singh", 23:"Kunal Bisht", 24:"Manisha Belwal", 25:"Manni",
       26:"Mayank Sharma", 27:"Mishika Rana", 28:"Narendra Modi", 29:"Netanya", 30:"Nishtha Goyal",
       31:"Pratham", 32:"Prerna Mehta", 33:"Priyanshu Gupta", 34:"Rahul Sharma", 35:"Rohit Gujjar",
       36:"Saksham Singh", 37:"Siddharth", 38:"Shivani",39:"Sneha Jindal", 40:"Swati Malik",
       41:"Tamana", 42:"Tanupriya Pal", 43:"Tushar", 44:"Udayveer", 45:"Utkarsh Singh",
       46:"Vaibhav Bhardwaj", 47:"Vansh", 48:"Vaani Mehta", 49:"Virat Kohli", 50:"Yashi"}

# %%
print("------------------------------------------------------------MARKS STATEMENT---------------------------------------------------------------------")
x = int(input("Enter Student Roll no.:"))
print("."*153)
y = list(dic.keys())

if x in y:
    Name = dic[x]
    print("Name Of The Student :",Name)
    print("."*153)

    
    marks = Students[Name].values()
    marks = sum(marks)
    print("Total Marks : 500")
    print("Marks Obtained :",marks)
    print("."*153)

    
    percentage = marks/5
    print(f"Percentage : {percentage}%")
    print("."*153)

    
    if percentage>=60:
        Division = "First Division"
    elif percentage>=50:
        Division = "Second Division"
    elif percentage>=33:
        Division = "Third Division"
    else:
        Division = "Fail"
    print("Division :",Division)
    print("."*153)


    
    if Division == "Fail":
        print("Result : Fail")
        print("Better Luck Next Time:(")
    else:
        print("Result : Pass")
        print("Congratulations",Name,"!!","Keep Up The Good Work:)")
             
else:
    print("Roll No. Not Found In The Record.")
# Out:
# ------------------------------------------------------------MARKS STATEMENT---------------------------------------------------------------------
# Enter Student Roll no.: 32
# .........................................................................................................................................................
# Name Of The Student : Prerna Mehta
# .........................................................................................................................................................
# Total Marks : 500
# Marks Obtained : 453
# .........................................................................................................................................................
# Percentage : 90.6%
# .........................................................................................................................................................
# Division : First Division
# ...

# %% [markdown]
# ![Screenshot (180).png](attachment:a4adf3c4-0592-4cd9-a6f9-e1c11f4a24d4.png)

# %%
Students = {"Abhishek Malhan":{"English":81,"Hindi":72,"Maths":79,"Science":86,"Social Studies":69},
            "Aradhya Bansal":{"English":95,"Hindi":88,"Maths":85,"Science":92,"Social Studies":90},
            "Ansh Sharma":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Aditya Rajput":{"English":32,"Hindi":30,"Maths":27,"Science":21,"Social Studies":29},
            "Bhavya Seth":{"English":70,"Hindi":72,"Maths":65,"Science":74,"Social Studies":78},
            "Bhumika Ratan":{"English":55,"Hindi":43,"Maths":39,"Science":49,"Social Studies":37},
            "Chetan Anand":{"English":88,"Hindi":60,"Maths":55,"Science":48,"Social Studies":74},
            "Chirag Parswan":{"English":89,"Hindi":92,"Maths":78,"Science":69,"Social Studies":85},
            "Dev Jindal":{"English":39,"Hindi":40,"Maths":67,"Science":28,"Social Studies":34},
            "Divya":{"English":56,"Hindi":59,"Maths":49,"Science":52,"Social Studies":47},
            "Divyanshu Mahajan":{"English":43,"Hindi":50,"Maths":72,"Science":66,"Social Studies":57},
            "Drishti Oberoi":{"English":78,"Hindi":49,"Maths":72,"Science":50,"Social Studies":56},
            "Gaurav Kumar":{"English":55,"Hindi":60,"Maths":77,"Science":89,"Social Studies":72},
            "Gautam Nijhawan":{"English":75,"Hindi":90,"Maths":67,"Science":65,"Social Studies":42},
            "Himanshu Rajput":{"English":66,"Hindi":82,"Maths":89,"Science":64,"Social Studies":57},
            "Harshit Sethi":{"English":85,"Hindi":80,"Maths":57,"Science":58,"Social Studies":60},
            "Hitika Verma":{"English":72,"Hindi":83,"Maths":77,"Science":38,"Social Studies":62},
            "Isha Yadav":{"English":64,"Hindi":60,"Maths":47,"Science":66,"Social Studies":57},
            "Ishaan Gupta":{"English":61,"Hindi":73,"Maths":53,"Science":60,"Social Studies":49},
            "Ishita Goel":{"English":78,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Kishan Goyal":{"English":68,"Hindi":62,"Maths":79,"Science":32,"Social Studies":45},
            "Khushi Singh":{"English":35,"Hindi":40,"Maths":32,"Science":29,"Social Studies":47},
            "Kunal Bisht":{"English":24,"Hindi":29,"Maths":32,"Science":30,"Social Studies":27},
            "Manisha Belwal":{"English":68,"Hindi":65,"Maths":49,"Science":58,"Social Studies":45},
            "Manni":{"English":72,"Hindi":81,"Maths":87,"Science":76,"Social Studies":80},
            "Mayank Sharma":{"English":75,"Hindi":60,"Maths":47,"Science":28,"Social Studies":32},
            "Mishika Rana":{"English":82,"Hindi":70,"Maths":67,"Science":89,"Social Studies":78},
            "Narendra Modi":{"English":43,"Hindi":89,"Maths":62,"Science":39,"Social Studies":91},
            "Netanya":{"English":64,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Nishtha Goyal":{"English":39,"Hindi":40,"Maths":26,"Science":36,"Social Studies":33},
            "Pratham":{"English":82,"Hindi":77,"Maths":90,"Science":78,"Social Studies":82},
            "Prerna Mehta":{"English":98,"Hindi":90,"Maths":88,"Science":92,"Social Studies":85},
            "Priyanshu Gupta":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Rahul Sharma":{"English":33,"Hindi":47,"Maths":34,"Science":11,"Social Studies":22},
            "Rohit Gujjar":{"English":62,"Hindi":71,"Maths":51,"Science":45,"Social Studies":58},
            "Saksham Singh":{"English":66,"Hindi":72,"Maths":53,"Science":59,"Social Studies":55},
            "Siddharth":{"English":72,"Hindi":80,"Maths":63,"Science":81,"Social Studies":52},
            "Shivani":{"English":75,"Hindi":70,"Maths":67,"Science":78,"Social Studies":62},
            "Sneha Jindal":{"English":59,"Hindi":70,"Maths":39,"Science":56,"Social Studies":64},
            "Swati Malik":{"English":93,"Hindi":89,"Maths":72,"Science":76,"Social Studies":69},
            "Tamana":{"English":50,"Hindi":46,"Maths":48,"Science":44,"Social Studies":34},
            "Tanupriya Pal":{"English":85,"Hindi":80,"Maths":79,"Science":82,"Social Studies":64},
            "Tushar":{"English":75,"Hindi":68,"Maths":79,"Science":65,"Social Studies":60},
            "Udayveer":{"English":92,"Hindi":80,"Maths":85,"Science":88,"Social Studies":73},
            "Utkarsh Singh":{"English":32,"Hindi":39,"Maths":28,"Science":34,"Social Studies":30},
            "Vaibhav Bhardwaj":{"English":69,"Hindi":70,"Maths":78,"Science":56,"Social Studies":65},
            "Vansh":{"English":40,"Hindi":53,"Maths":32,"Science":48,"Social Studies":31},
            "Vaani Mehta":{"English":52,"Hindi":41,"Maths":34,"Science":40,"Social Studies":35},
            "Virat Kohli":{"English":88,"Hindi":77,"Maths":90,"Science":74,"Social Studies":67},
            "Yashi":{"English":90,"Hindi":91,"Maths":83,"Science":77,"Social Studies":85}}

# %%
print("-----------------------------------------------------------MARKS STATEMENT---------------------------------------------------------------------")
x = str(input("Enter Student Name:")).title()
y = list(Students.keys())
print("."*153)


if x in y:
    marks = sum(Students[x].values())
    print("Total Marks : 500")
    print("Marks Obtained :",marks)
    print("."*153)

    percentage = marks/5
    print(f"Percentage : {percentage}%")
    print("."*153)

    
    if percentage>=60:
        Division = "First Division"
    elif percentage>=50:
        Division = "Second Division"
    elif percentage>=33:
        Division = "Third Division"
    else:
        Division = "Fail"
    
    print("Division :",Division)
    print("."*153)


    
    if Division == "Fail":
        print("Result : Fail")
        print("Better Luck Next Time:(")
    else:
        print("Result : Pass")
        print("Congratulations",x,"!!","Keep Up The Good Work:)")

else:
    print("Student Name not found in the record.")
# Out:
# -----------------------------------------------------------MARKS STATEMENT---------------------------------------------------------------------
# Enter Student Name: Mayank Sharma
# .........................................................................................................................................................
# Total Marks : 500
# Marks Obtained : 242
# .........................................................................................................................................................
# Percentage : 48.4%
# .........................................................................................................................................................
# Division : Third Division
# .........................................................................................................................................................
# Result : Pass
# Congratulations Mayank Sharma !! Keep Up The Good Work:)

# %% [markdown]
# ![Screenshot (181).png](attachment:d2275b65-b1a3-4692-889b-8ddb253a931f.png)
